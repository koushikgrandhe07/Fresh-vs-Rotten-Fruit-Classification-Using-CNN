# %%
import os
import matplotlib.pyplot as plt
from PIL import Image
from collections import Counter

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image
from collections import Counter

# Set the path to your dataset
dataset_path = 'Fruit_dataset'

# List all subfolders and count images per folder
subfolders = [f.name for f in os.scandir(dataset_path) if f.is_dir()]
image_counts = {}

for folder in subfolders:
    folder_path = os.path.join(dataset_path, folder)
    image_counts[folder] = len(os.listdir(folder_path))

# Plot the distribution of images per class
plt.figure(figsize=(12, 6))
plt.bar(image_counts.keys(), image_counts.values(), color='skyblue')
plt.xticks(rotation=90)
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.title('Image Count per Class')
plt.show()

# Display sample images for each class
fig, axes = plt.subplots(4, 4, figsize=(12, 12))
for i, folder in enumerate(subfolders[:16]):  # Adjust as needed
    folder_path = os.path.join(dataset_path, folder)
    sample_image = Image.open(os.path.join(folder_path, os.listdir(folder_path)[0]))
    ax = axes[i // 4, i % 4]
    ax.imshow(sample_image)
    ax.axis('off')
    ax.set_title(folder)

plt.tight_layout()
plt.show()

# %%
# exploratory data analysis (EDA)

# %%
from sklearn.model_selection import train_test_split
import shutil

# Paths for the splits
train_dir = 'Fruit_dataset_split/train'
val_dir = 'Fruit_dataset_split/val'
test_dir = 'Fruit_dataset_split/test'

# Create directories for each split
for split_dir in [train_dir, val_dir, test_dir]:
    os.makedirs(split_dir, exist_ok=True)
    for folder in subfolders:
        os.makedirs(os.path.join(split_dir, folder), exist_ok=True)

# Split images for each class
for folder in subfolders:
    folder_path = os.path.join(dataset_path, folder)
    images = os.listdir(folder_path)
    
    # Splitting the data
    train_images, temp_images = train_test_split(images, test_size=0.3, random_state=42)
    val_images, test_images = train_test_split(temp_images, test_size=0.5, random_state=42)

    # Moving images to respective directories
    for img in train_images:
        shutil.copy(os.path.join(folder_path, img), os.path.join(train_dir, folder, img))
    for img in val_images:
        shutil.copy(os.path.join(folder_path, img), os.path.join(val_dir, folder, img))
    for img in test_images:
        shutil.copy(os.path.join(folder_path, img), os.path.join(test_dir, folder, img))

print("Data splitting completed successfully!")

# %%
from PIL import Image
import os

# Define target size for resizing
target_size = (128, 128)

# Set paths for the original split and preprocessed directories
split_dir = 'Fruit_dataset_split'
preprocessed_dir = 'Fruit_dataset_preprocessed'

# Create directories for each split in the preprocessed folder
for split in ['train', 'val', 'test']:
    split_path = os.path.join(preprocessed_dir, split)
    os.makedirs(split_path, exist_ok=True)
    
    # Create class-specific folders
    class_folders = os.listdir(os.path.join(split_dir, split))
    for class_folder in class_folders:
        os.makedirs(os.path.join(split_path, class_folder), exist_ok=True)

        # Process images within each class folder
        class_path = os.path.join(split_dir, split, class_folder)
        images = os.listdir(class_path)
        for img_name in images:
            img_path = os.path.join(class_path, img_name)
            
            # Open, resize, and normalize the image
            img = Image.open(img_path).convert('RGB')  # Convert to RGB
            img = img.resize(target_size)
            
            # Save the processed image in the new directory
            img.save(os.path.join(split_path, class_folder, img_name))

print("Image resizing and normalization completed successfully!")

# %%
## Build and Train the Model

# %%
import tensorflow as tf
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\User1\anaconda3\Lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#     app.start()
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "C:\Users\User1\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\User1\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Users\User1\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Users\User1\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3024, in run_cell
#     result = self._run_cell(
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3079, in _run_cell
#     result = runner(coro)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3284, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3466, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\User1\AppData\Local\Temp\ipykernel_22136\3793406994.py", line 1, in <module>
#     import tensorflow as tf
#   File "C:\Users\User1\anaconda3\Lib\site-packages\tensorflow\__init__.py", line 467, in <module>
#     importlib.import_module("keras.src.optimizers")
#   File "C:\Users\User1\anaconda3\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\__init__.py", line 4, in <module>
#     from keras.api import DTypePolicy
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\api\__init__.py", line 8, in <module>
#     from keras.api import activations
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\api\activations\__init__.py", line 7, in <module>
#     from keras.src.activations import deserialize
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\__init__.py", line 1, in <module>
#     from keras.src import activations
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\activations\__init__.py", line 22, in <module>
#     from keras.src.saving import object_registration
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\saving\__init__.py", line 7, in <module>
#     from keras.src.saving.saving_api import load_model
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\saving\saving_api.py", line 7, in <module>
#     from keras.src.legacy.saving import legacy_h5_format
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py", line 13, in <module>
#     from keras.src.legacy.saving import saving_utils
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\legacy\saving\saving_utils.py", line 10, in <module>
#     from keras.src import models
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\models\__init__.py", line 1, in <module>
#     from keras.src.models.functional import Functional
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\models\functional.py", line 16, in <module>
#     from keras.src.models.model import Model
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\models\model.py", line 12, in <module>
#     from keras.src.trainers import trainer as base_trainer
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\trainers\trainer.py", line 14, in <module>
#     from keras.src.trainers.data_adapters import data_adapter_utils
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\__init__.py", line 4, in <module>
#     from keras.src.trainers.data_adapters import array_data_adapter
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py", line 7, in <module>
#     from keras.src.trainers.data_adapters import array_slicing
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_slicing.py", line 11, in <module>
#     import pandas
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\__init__.py", line 39, in <module>
#     from pandas.compat import (
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\compat\__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\compat\pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pyarrow\__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\User1\anaconda3\Lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#     app.start()
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "C:\Users\User1\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\User1\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Users\User1\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Users\User1\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3024, in run_cell
#     result = self._run_cell(
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3079, in _run_cell
#     result = runner(coro)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3284, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3466, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\User1\AppData\Local\Temp\ipykernel_22136\3793406994.py", line 1, in <module>
#     import tensorflow as tf
#   File "C:\Users\User1\anaconda3\Lib\site-packages\tensorflow\__init__.py", line 467, in <module>
#     importlib.import_module("keras.src.optimizers")
#   File "C:\Users\User1\anaconda3\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\__init__.py", line 4, in <module>
#     from keras.api import DTypePolicy
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\api\__init__.py", line 8, in <module>
#     from keras.api import activations
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\api\activations\__init__.py", line 7, in <module>
#     from keras.src.activations import deserialize
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\__init__.py", line 1, in <module>
#     from keras.src import activations
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\activations\__init__.py", line 22, in <module>
#     from keras.src.saving import object_registration
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\saving\__init__.py", line 7, in <module>
#     from keras.src.saving.saving_api import load_model
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\saving\saving_api.py", line 7, in <module>
#     from keras.src.legacy.saving import legacy_h5_format
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py", line 13, in <module>
#     from keras.src.legacy.saving import saving_utils
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\legacy\saving\saving_utils.py", line 10, in <module>
#     from keras.src import models
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\models\__init__.py", line 1, in <module>
#     from keras.src.models.functional import Functional
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\models\functional.py", line 16, in <module>
#     from keras.src.models.model import Model
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\models\model.py", line 12, in <module>
#     from keras.src.trainers import trainer as base_trainer
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\trainers\trainer.py", line 14, in <module>
#     from keras.src.trainers.data_adapters import data_adapter_utils
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\__init__.py", line 4, in <module>
#     from keras.src.trainers.data_adapters import array_data_adapter
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py", line 7, in <module>
#     from keras.src.trainers.data_adapters import array_slicing
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_slicing.py", line 11, in <module>
#     import pandas
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\__init__.py", line 62, in <module>
#     from pandas.core.api import (
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\core\api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\core\dtypes\dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pyarrow\__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\User1\anaconda3\Lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#     app.start()
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "C:\Users\User1\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\User1\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Users\User1\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Users\User1\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3024, in run_cell
#     result = self._run_cell(
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3079, in _run_cell
#     result = runner(coro)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3284, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3466, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\User1\AppData\Local\Temp\ipykernel_22136\3793406994.py", line 1, in <module>
#     import tensorflow as tf
#   File "C:\Users\User1\anaconda3\Lib\site-packages\tensorflow\__init__.py", line 467, in <module>
#     importlib.import_module("keras.src.optimizers")
#   File "C:\Users\User1\anaconda3\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\__init__.py", line 4, in <module>
#     from keras.api import DTypePolicy
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\api\__init__.py", line 8, in <module>
#     from keras.api import activations
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\api\activations\__init__.py", line 7, in <module>
#     from keras.src.activations import deserialize
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\__init__.py", line 1, in <module>
#     from keras.src import activations
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\activations\__init__.py", line 22, in <module>
#     from keras.src.saving import object_registration
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\saving\__init__.py", line 7, in <module>
#     from keras.src.saving.saving_api import load_model
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\saving\saving_api.py", line 7, in <module>
#     from keras.src.legacy.saving import legacy_h5_format
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py", line 13, in <module>
#     from keras.src.legacy.saving import saving_utils
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\legacy\saving\saving_utils.py", line 10, in <module>
#     from keras.src import models
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\models\__init__.py", line 1, in <module>
#     from keras.src.models.functional import Functional
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\models\functional.py", line 16, in <module>
#     from keras.src.models.model import Model
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\models\model.py", line 12, in <module>
#     from keras.src.trainers import trainer as base_trainer
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\trainers\trainer.py", line 14, in <module>
#     from keras.src.trainers.data_adapters import data_adapter_utils
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\__init__.py", line 4, in <module>
#     from keras.src.trainers.data_adapters import array_data_adapter
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py", line 7, in <module>
#     from keras.src.trainers.data_adapters import array_slicing
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_slicing.py", line 11, in <module>
#     import pandas
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\__init__.py", line 62, in <module>
#     from pandas.core.api import (
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\core\arrays\arrow\array.py", line 50, in <module>
#     from pandas.core import (
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\core\ops\__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\core\computation\check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "C:\Users\User1\anaconda3\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\numexpr\__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\User1\anaconda3\Lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#     app.start()
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "C:\Users\User1\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\User1\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Users\User1\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Users\User1\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\User1\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3024, in run_cell
#     result = self._run_cell(
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3079, in _run_cell
#     result = runner(coro)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3284, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3466, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\User1\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\User1\AppData\Local\Temp\ipykernel_22136\3793406994.py", line 1, in <module>
#     import tensorflow as tf
#   File "C:\Users\User1\anaconda3\Lib\site-packages\tensorflow\__init__.py", line 467, in <module>
#     importlib.import_module("keras.src.optimizers")
#   File "C:\Users\User1\anaconda3\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\__init__.py", line 4, in <module>
#     from keras.api import DTypePolicy
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\api\__init__.py", line 8, in <module>
#     from keras.api import activations
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\api\activations\__init__.py", line 7, in <module>
#     from keras.src.activations import deserialize
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\__init__.py", line 1, in <module>
#     from keras.src import activations
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\activations\__init__.py", line 22, in <module>
#     from keras.src.saving import object_registration
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\saving\__init__.py", line 7, in <module>
#     from keras.src.saving.saving_api import load_model
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\saving\saving_api.py", line 7, in <module>
#     from keras.src.legacy.saving import legacy_h5_format
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py", line 13, in <module>
#     from keras.src.legacy.saving import saving_utils
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\legacy\saving\saving_utils.py", line 10, in <module>
#     from keras.src import models
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\models\__init__.py", line 1, in <module>
#     from keras.src.models.functional import Functional
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\models\functional.py", line 16, in <module>
#     from keras.src.models.model import Model
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\models\model.py", line 12, in <module>
#     from keras.src.trainers import trainer as base_trainer
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\trainers\trainer.py", line 14, in <module>
#     from keras.src.trainers.data_adapters import data_adapter_utils
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\__init__.py", line 4, in <module>
#     from keras.src.trainers.data_adapters import array_data_adapter
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py", line 7, in <module>
#     from keras.src.trainers.data_adapters import array_slicing
#   File "C:\Users\User1\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_slicing.py", line 11, in <module>
#     import pandas
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\__init__.py", line 62, in <module>
#     from pandas.core.api import (
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\core\arrays\arrow\array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py", line 60, in <module>
#     from pandas.core import (
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\core\nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "C:\Users\User1\anaconda3\Lib\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "C:\Users\User1\anaconda3\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\User1\anaconda3\Lib\site-packages\bottleneck\__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, GlobalAveragePooling2D

# %%
import os

# %%
# Paths to preprocessed data
preprocessed_dir = 'Fruit_dataset_preprocessed'
train_dir = os.path.join(preprocessed_dir, 'train')
val_dir = os.path.join(preprocessed_dir, 'val')
test_dir = os.path.join(preprocessed_dir, 'test')

# %%
# Image parameters
target_size = (128, 128)  # Match the size from preprocessing
batch_size = 32
num_classes = len(os.listdir(train_dir))

# Image data generators
train_datagen = ImageDataGenerator(rescale=1.0 / 255)  # Normalize pixel values
val_datagen = ImageDataGenerator(rescale=1.0 / 255)

# %%
# Image parameters
target_size = (128, 128)  # Match the size from preprocessing
batch_size = 32
num_classes = len(os.listdir(train_dir))

# Image data generators
train_datagen = ImageDataGenerator(rescale=1.0 / 255)  # Normalize pixel values
val_datagen = ImageDataGenerator(rescale=1.0 / 255)
# Out:
# Found 16012 images belonging to 16 classes.
# Found 3431 images belonging to 16 classes.

# %%
# Load the pretrained VGG16 model
vgg_base = VGG16(
    weights='imagenet',  # Use pretrained weights
    include_top=False,   # Exclude the fully connected layers
    input_shape=(128, 128, 3)
)

# Freeze the base layers (so their weights don't update during training)
vgg_base.trainable = False

# %%
# Build the model
model = Sequential([
    vgg_base,
    GlobalAveragePooling2D(),  # Replaces Flatten for better performance
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')  # Final layer for classification
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=30
)
# Out:
# C:\Users\User1\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1090s 2s/step - accuracy: 0.3968 - loss: 1.8288 - val_accuracy: 0.7339 - val_loss: 0.8949
# Epoch 2/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1044s 2s/step - accuracy: 0.6923 - loss: 0.9438 - val_accuracy: 0.7852 - val_loss: 0.6505
# Epoch 3/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1049s 2s/step - accuracy: 0.7645 - loss: 0.7254 - val_accuracy: 0.8275 - val_loss: 0.5380
# Epoch 4/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1057s 2s/step - accuracy: 0.7989 - loss: 0.6130 - val_accuracy: 0.8397 - val_loss: 0.4859
# Epoch 5/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 998s 2s/step - accuracy: 0.8159 - loss: 0.5602 - val_accuracy: 0.8473 - val_loss: 0.4491
# Epoch 6/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 972s 2s/step - accuracy: 0.8316 - loss: 0.5123 - val_accuracy: 0.8671 - val_loss: 0.4044
# Epoch 7/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 992s 2s/step - accuracy: 0.8463 - loss: 0.4698 - val_accuracy: 0.8750 - val_loss: 0.3695
# Epoch 8/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 965s 2s/step - accuracy: 0.8624 - loss: 0.4271 - val_accuracy: 0.8820 - val_loss: 0.3501
# Epoch 9/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1014s 2s/step - accuracy: 0.8613 - loss: 0.4174 - val_accuracy: 0.8890 - val_loss: 0.3368
# Epoch 10/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1023s 2s/step - accuracy: 0.8678 - loss: 0.4005 - val_accuracy: 0.8959 - val_loss: 0.3176
# Epoch 11/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1027s 2s/step - accuracy: 0.8749 - loss: 0.3743 - val_accuracy: 0.8942 - val_loss: 0.3145
# Epoch 12/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1021s 2s/step - accuracy: 0.8780 - loss: 0.3538 - val_accuracy: 0.9038 - val_loss: 0.3021
# Epoch 13/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1018s 2s/step - accuracy: 0.8801 - loss: 0.3456 - val_accuracy: 0.9018 - val_loss: 0.2954
# Epoch 14/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 15657s 31s/step - accuracy: 0.8882 - loss: 0.3331 - val_accuracy: 0.9082 - val_loss: 0.2813
# Epoch 15/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1005s 2s/step - accuracy: 0.8987 - loss: 0.3088 - val_accuracy: 0.9082 - val_loss: 0.2794
# Epoch 16/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1029s 2s/step - accuracy: 0.8946 - loss: 0.3186 - val_accuracy: 0.9146 - val_loss: 0.2680
# Epoch 17/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1026s 2s/step - accuracy: 0.9005 - loss: 0.2948 - val_accuracy: 0.9091 - val_loss: 0.2766
# Epoch 18/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1030s 2s/step - accuracy: 0.9011 - loss: 0.2900 - val_accuracy: 0.9126 - val_loss: 0.2671
# Epoch 19/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 3498s 7s/step - accuracy: 0.9059 - loss: 0.2781 - val_accuracy: 0.9196 - val_loss: 0.2585
# Epoch 20/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1028s 2s/step - accuracy: 0.9037 - loss: 0.2839 - val_accuracy: 0.9140 - val_loss: 0.2525
# Epoch 21/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1032s 2s/step - accuracy: 0.9061 - loss: 0.2693 - val_accuracy: 0.9181 - val_loss: 0.2486
# Epoch 22/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1034s 2s/step - accuracy: 0.9088 - loss: 0.2699 - val_accuracy: 0.9204 - val_loss: 0.2446
# Epoch 23/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1045s 2s/step - accuracy: 0.9156 - loss: 0.2515 - val_accuracy: 0.9248 - val_loss: 0.2416
# Epoch 24/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1021s 2s/step - accuracy: 0.9157 - loss: 0.2434 - val_accuracy: 0.9210 - val_loss: 0.2375
# Epoch 25/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1015s 2s/step - accuracy: 0.9147 - loss: 0.2469 - val_accuracy: 0.9289 - val_loss: 0.2326
# Epoch 26/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1028s 2s/step - accuracy: 0.9194 - loss: 0.2334 - val_accuracy: 0.9266 - val_loss: 0.2361
# Epoch 27/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1014s 2s/step - accuracy: 0.9223 - loss: 0.2271 - val_accuracy: 0.9222 - val_loss: 0.2400
# Epoch 28/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1010s 2s/step - accuracy: 0.9215 - loss: 0.2243 - val_accuracy: 0.9315 - val_loss: 0.2290
# Epoch 29/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1016s 2s/step - accuracy: 0.9221 - loss: 0.2204 - val_accuracy: 0.9198 - val_loss: 0.2365
# Epoch 30/30
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 1028s 2s/step - accuracy: 0.9244 - loss: 0.2215 - val_accuracy: 0.9219 - val_loss: 0.2465

# %%
# Save the model
model.save('fruit_classifier_vgg16.h5')
print("Model training completed and saved as 'fruit_classifier_vgg16.h5'")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model training completed and saved as 'fruit_classifier_vgg16.h5'

# %%
print("finished")
# Out:
# finished

# %%
import matplotlib.pyplot as plt

# Plot training and validation accuracy
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Plot training and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()
