# %%
# exploratory data analysis (EDA)

# %%
import os

# %%
import matplotlib.pyplot as plt

# %%
pip install --upgrade matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\user1\anaconda3\lib\site-packages (3.7.2)
# Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/8b/ce/15b0bb2fb29b3d46211d8ca740b96b5232499fc49200b58b8d571292c9a6/matplotlib-3.9.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading matplotlib-3.9.2-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user1\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\user1\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.2-cp311-cp311-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.8 MB 991.0 kB/s eta 0:00:08
#     --------------------------------------- 0.2/7.8 MB 1.9 MB/s eta 0:00:05
#    - -------------------------------------- 0.2/7.8 MB 1.8 MB/s eta 0:00:05
#    - -------------------------------------- 0.2/7.8 MB 1.8 MB/s eta 0:00:05
#    -- ------------------------------------- 0.5/7.8 MB 2.1 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/7.8 MB 2.4 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/7.8 MB 2.0 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/7.8 MB 2.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.0/7.8 MB 2.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.1/7.8 MB 2.5 MB/s eta 0:00:03
#    ------ --------------------------------- 1.2/7.8 MB 2.6 MB/s eta 0:00:03
#    ------ --------------------------------- 1.3/7.8 MB 2.5 MB/s eta 0:00:03
#    ------- -------------------------------- 1.5/7.8 MB 2.6 MB/s eta 0:00:03
#    -------- ------------------------------- 1.6/7.8 MB 2.6 MB/s eta 0:00:03
#    -------- ------------------------------- 1.7/7.8 MB 2.6 MB/s eta 0:00:03
#    --------- ------------------------------ 1.8/7.8 MB 2.6 MB/s eta 0:00:03
#    --------- ------------------------------ 1.9/7.8 MB 2.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.0/7.8 MB 2.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.1/7.8 MB 2.5 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.2/7.8 MB 2.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.3/7.8 MB 2.5 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.3/7.8 MB 2.5 MB/s eta 0:00:03
#    ------------ --------------------------- 2.4/7.8 MB 2.5 MB/s eta 0:00:03
#    ------------ --------------------------- 2.5/7.8 MB 2.5 MB/s eta 0:00:03
#    ------------- -------------------------- 2.7/7.8 MB 2.5 MB/s eta 0:00:03
#    -------------- ------------------------- 2.8/7.8 MB 2.5 MB/s eta 0:00:02
#    --------------- ------------------------ 2.9/7.8 MB 2.5 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/7.8 MB 2.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.2/7.8 MB 2.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.3/7.8 MB 2.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.4/7.8 MB 2.6 MB/s eta 0:00:02
#    ------------------ --------------------- 3.6/7.8 MB 2.6 MB/s eta 0:00:02
#    ------------------ --------------------- 3.7/7.8 MB 2.6 MB/s eta 0:00:02
#    ------------------- -------------------- 3.8/7.8 MB 2.6 MB/s eta 0:00:02
#    -------------------- ------------------- 4.0/7.8 MB 2.6 MB/s eta 0:00:02
#    --------------------- ------------------ 4.1/7.8 MB 2.6 MB/s eta 0:00:02
#    --------------------- ------------------ 4.3/7.8 MB 2.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.4/7.8 MB 2.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.5/7.8 MB 2.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.6/7.8 MB 2.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.7/7.8 MB 2.6 MB/s eta 0:00:02
#    ------------------------ --------------- 4.8/7.8 MB 2.6 MB/s eta 0:00:02
#    ------------------------ --------------- 4.9/7.8 MB 2.6 MB/s eta 0:00:02
#    ------------------------- -------------- 4.9/7.8 MB 2.6 MB/s eta 0:00:02
#    ------------------------- -------------- 5.1/7.8 MB 2.6 MB/s eta 0:00:02
#    -------------------------- ------------- 5.2/7.8 MB 2.6 MB/s eta 0:00:02
#    -------------------------- ------------- 5.2/7.8 MB 2.6 MB/s eta 0:00:02
#    --------------------------- ------------ 5.3/7.8 MB 2.6 MB/s eta 0:00:01
#    --------------------------- ------------ 5.4/7.8 MB 2.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.6/7.8 MB 2.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.7/7.8 MB 2.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.7/7.8 MB 2.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.9/7.8 MB 2.6 MB/s eta 0:00:01
#    ------------------------------ --------- 5.9/7.8 MB 2.6 MB/s eta 0:00:01
#    ------------------------------- -------- 6.1/7.8 MB 2.6 MB/s eta 0:00:01
#    ------------------------------- -------- 6.2/7.8 MB 2.6 MB/s eta 0:00:01
#    -------------------------------- ------- 6.3/7.8 MB 2.6 MB/s eta 0:00:01
#    -------------------------------- ------- 6.4/7.8 MB 2.6 MB/s eta 0:00:01
#    --------------------------------- ------ 6.5/7.8 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.7/7.8 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.8/7.8 MB 2.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.0/7.8 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------ --- 7.1/7.8 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------ --- 7.2/7.8 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------- -- 7.4/7.8 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------- -- 7.4/7.8 MB 2.6 MB/s eta 0:00:01
#    -------------------------------------- - 7.6/7.8 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  7.7/7.8 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  7.8/7.8 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  7.8/7.8 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 2.6 MB/s eta 0:00:00
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.2
#     Uninstalling matplotlib-3.7.2:
#       Successfully uninstalled matplotlib-3.7.2
# Successfully installed matplotlib-3.9.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image
from collections import Counter

# Set the path to your dataset
dataset_path = 'Fruit_dataset'

# List all subfolders and count images per folder
subfolders = [f.name for f in os.scandir(dataset_path) if f.is_dir()]
image_counts = {}

for folder in subfolders:
    folder_path = os.path.join(dataset_path, folder)
    image_counts[folder] = len(os.listdir(folder_path))

# Plot the distribution of images per class
plt.figure(figsize=(12, 6))
plt.bar(image_counts.keys(), image_counts.values(), color='skyblue')
plt.xticks(rotation=90)
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.title('Image Count per Class')
plt.show()

# Display sample images for each class
fig, axes = plt.subplots(4, 4, figsize=(12, 12))
for i, folder in enumerate(subfolders[:16]):  # Adjust as needed
    folder_path = os.path.join(dataset_path, folder)
    sample_image = Image.open(os.path.join(folder_path, os.listdir(folder_path)[0]))
    ax = axes[i // 4, i % 4]
    ax.imshow(sample_image)
    ax.axis('off')
    ax.set_title(folder)

plt.tight_layout()
plt.show()
